# %% [markdown]
# ### Q1. Explain GET and POST methods.

# %% [markdown]
# ### GET : GET requests in Flask, we use the @app.route decorator, which maps a URL to a Python function that generates the response. By default, Flask treats a route function as a GET request handler. Here's an example:

# %%
from flask import Flask

app = Flask(__name__)

@app.route('/')
def index():
    return 'Hello, World!'

if __name__ == '__main__':
    app.run(host="0.0.0.0")

# %% [markdown]
# ### POST: POST requests in Flask, we can use the methods parameter of the @app.route decorator. We use it so that we can take data from the user. Here's an example:

# %%
from flask import Flask, request

app = Flask(__name__)

@app.route('/login', methods=['POST'])
def login():
    username = request.form['username']
    password = request.form['password']
    return 'Logged in successfully'

if __name__ == '__main__':
    app.run(host="0.0.0.0")

# %% [markdown]
# ### Q2. Why is request used in Flask?

# %% [markdown]
# ### The request module in Flask is used to access incoming request data in Flask applications. When a client (such as a web browser) sends a request to a Flask web application, the application can use the request  module to access information about the request, such as the HTTP method used (e.g. GET, POST, etc.), the  data sent in the request body (if any), and any parameters or data sent as part of the request URL.

# %% [markdown]
# ### Q3. Why is redirect() used in Flask?

# %% [markdown]
# ### The redirect() function in Flask is used to redirect the user to a different URL or route within a Flask application. When a Flask application receives a request, it can use the redirect() function to send the user to a different URL or route, which can be useful for a variety of reasons.

# %%
from flask import Flask, redirect, url_for

app = Flask(__name__)

@app.route('/')
def index():
    return redirect(url_for('login'))

@app.route('/login')
def login():
    return 'Please log in'

if __name__ == '__main__':
    app.run(host="0.0.0.0")

# %% [markdown]
# ### Q4. What are templates in Flask? Why is the render_template() function used?

# %% [markdown]
# ### Templates in Flask are files that contain HTML, CSS, and other content that is used to generate dynamic web pages. Flask uses the Jinja2 templating engine, which allows developers to create templates that can be populated with data from their Python code.
#
# ### The render_template() function in Flask is used to render a template and return the resulting HTML to the client's web browser. This function takes the name of a template file as its first argument and any additional arguments are used to populate the template with data.

# %%
from flask import Flask, render_template

app = Flask(__name__)

@app.route('/')
def index():
    return render_template('index.html')

if __name__ == '__main__':
    app.run(host="0.0.0.0")

# %% [markdown]
# ### Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook.

# %%
from flask import Flask, request, jsonify

app = Flask(__name__)

@app.route('/data', methods=['POST'])
def Func():
    data = request.get_json()  
    return jsonify({'received_data': data})


if __name__ == '__main__':
    app.run(host="0.0.0.0")

# %% [markdown]
# ![Screenshot 2023-07-03 123133.png](attachment:4e82765f-a5fb-4118-adcf-b0935b02d4c3.png)
